# %% [markdown]
# # Introduction

# %% [markdown]
# Montreal (Canada) is the second biggest french speaking city in the world after Paris (1), it is an attractive part of Canada that attracts millions of immigrants and tourists every year. Montreal has a multinational cultural heritage that makes its cultural landscape particularly vibrant, and this is clearly reflected through the richness and diversity of the restauration scene. The food industry in Montreal is very cosmopolitain with diverse set of menues from all over the planet(1) In addition to that, Montreal has the highest restaurants per capita in north America after New York, which makes the Restauration industry highly competitive sector especially for the well established cultures like the Italian culture. Montreal is home for one fifth of Canadians with Italian decent, and opening an Italian restaurant business is not a simple task.
#
# (1) https://www.geosmontreal.com/visiting-montreal/10-facts-about-montreal.htm

# %% [markdown]
# # Problem

# %% [markdown]
# In order to open a restarant to serve italian pizzas, choosing the right location in Montreal is crucial for the success of the business.
#
# It is important to locate the best available spots around the city, and with no doupt there is a lot of potential locations that appears on the map: Beautiful neighborhoods, many walkable areas, easy access by public transport means and bikes, closeness to museums and parks...
#
# In this study, we will work on identifying the list of adresses for best possible location to open a Pizza restaurant.
